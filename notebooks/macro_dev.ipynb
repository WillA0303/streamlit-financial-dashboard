# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\willa\\Jupyter'

# %%
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path

# Absolute path to your macro data folder
macro_path = Path(r"C:\Users\willa\Python Project\data\macro")

from modules.macro_engine.basic import add_macro_features, macro_summary_v11

macro_path, list(macro_path.glob("*.csv"))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 8
#       5 # Absolute path to your macro data folder
#       6 macro_path = Path(r"C:\Users\willa\Python Project\data\macro")
# ----> 8 from modules.macro_engine.basic import add_macro_features, macro_summary_v11
#      10 macro_path, list(macro_path.glob("*.csv"))
#
# ModuleNotFoundError: No module named 'modules'
